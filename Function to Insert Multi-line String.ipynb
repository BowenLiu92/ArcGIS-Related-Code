# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd

df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_Inflow.xlsx', sheet_name = 'Bath')
df.head()
# Out:
#                               Municipalities  Count     Share
# 0           Moore township (Northampton, PA)     81  0.139896
# 1             Bath borough (Northampton, PA)     55  0.094991
# 2  Lower Nazareth township (Northampton, PA)     36  0.062176
# 3           Bethlehem city (Northampton, PA)     32  0.055268
# 4      East Allen township (Northampton, PA)     32  0.055268

# %%
df2 = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_Inflow.xlsx', sheet_name = 'Allentown')
df2
# Out:
#                                  Municipalities  Count     Share
# 0                   Allentown city (Lehigh, PA)   9515  0.210128
# 1               Whitehall township (Lehigh, PA)   1914  0.042268
# 2              Bethlehem city (Northampton, PA)   1895  0.041849
# 3          Lower Macungie township (Lehigh, PA)   1603  0.035400
# 4         South Whitehall township (Lehigh, PA)   1514  0.033435
# 5          Upper Macungie township (Lehigh, PA)   1213  0.026788
# 6               Salisbury township (Lehigh, PA)   1100  0.024292
# 7                   Bethlehem city (Lehigh, PA)   1006  0.022216
# 8         North Whitehall township (Lehigh, PA)    955  0.021090
# 9                   Emmaus borough (Lehigh, PA)    759  0.016762
# 10         Bethlehem township (Northampton, PA)    719  0.015878
# 11        Northampton borough (Northampton, PA)    641  0.014156
# 12           Upper Saucon township (Lehigh, PA)    614  0.013559
# ...

# %%
xl = pd.ExcelFile('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_Inflow.xlsx')
xl.sheet_names
# Out:
# ['Alburtis',
#  'Allen',
#  'Allentown',
#  'Bangor',
#  'Bath',
#  'Bethlehem',
#  'Bethlehem Township',
#  'Bushkill',
#  'Catasauqua',
#  'Chapman',
#  'Coopersburg',
#  'Coplay',
#  'East Allen',
#  'East Bangor',
#  'Easton',
#  'Emmaus',
#  'Forks',
#  'Fountain Hill',
#  'Freemansburg',
#  'Glendon',
#  'Hanover (LC)',
#  'Hanover (NC)',
#  'Heidelberg',
#  'Hellertown',
#  'Lehigh Township',
#  'Lower Macungie',
#  'Lower Milford',
#  'Lower Mount Bethel',
#  'Lower Nazareth',
#  'Lower Saucon',
#  'Lowhill',
#  'Lynn',
#  'Macungie',
#  'Moore',
#  'Nazareth',
#  'North Catasauqua',
#  'North Whitehall',
#  'Northampton',
#  'Palmer',
#  'Pen Argyl',
#  'Plainfield',
#  'Portland',
#  'Roseto',
#  'Salisbury',
#  'Slatington',
#  'South Whitehall',
#  'Stockertown',
#  'Tatamy',
#  'Upper Macungie',
#  'Upper Milford',
#  'Upper Mount Bethel',
#  'Upper Nazareth',
#  'Upper Saucon',
#  'Walnutport',
#  'Washington (LC)',
#  'Washington (NC)',
#  'Weisenberg',
# ...

# %%
df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_inflow.xlsx', sheet_name = 'Bath')

df['Merge'] = df['Municipalities'] + df['Count'].astype(str)

# %%
df['Merge'] = df['Municipalities'] + str(" "*5)+ df['Count'].astype(str)

# %%
s = df['Merge']
s.head()
# Out:
# 0             Moore township (Northampton, PA)     81
# 1               Bath borough (Northampton, PA)     55
# 2    Lower Nazareth township (Northampton, PA)     36
# 3             Bethlehem city (Northampton, PA)     32
# 4        East Allen township (Northampton, PA)     32
# Name: Merge, dtype: object

# %%
s2 = '\n'.join(s)

# %%
s1 = s.str.cat(sep=';  \n ')
print(s1)
# Out:
# Moore township (Northampton, PA)     81;
#  Bath borough (Northampton, PA)     55;
#  Lower Nazareth township (Northampton, PA)     36;
#  Bethlehem city (Northampton, PA)     32;
#  East Allen township (Northampton, PA)     32;
#  Lehigh township (Northampton, PA)     25;
#  Upper Nazareth township (Northampton, PA)     21;
#  Bushkill township (Northampton, PA)     15;
#  Bethlehem township (Northampton, PA)     14;
#  Northampton borough (Northampton, PA)     14;
#  Allentown city (Lehigh, PA)     13;
#  Whitehall township (Lehigh, PA)     13;
#  Bethlehem city (Lehigh, PA)     10;
#  Forks township (Northampton, PA)     10;
#  Polk township (Monroe, PA)     9;
#  Nazareth borough (Northampton, PA)     9;
#  Lower Macungie township (Lehigh, PA)     8;
#  Allen township (Northampton, PA)     8;
#  Palmer township (Northampton, PA)     7;
#  Brooklyn borough (Kings, NY)     6;
#  Wilson borough (Northampton, PA)     6;
#  Chestnuthill township (Monroe, PA)     5;
# ...

# %%
#From Pandas documentation on str join
import numpy as np
s = pd.Series(['a', 'b', np.nan, 'd'])
s
s.str.cat()

# %%
#Put everything together into a function
#This is for municipalities
def TableOnline(x):
    df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All.xlsx', sheet_name = x)
    df['Merge'] = df['Municipalities'] + str("    ")+ df['Count'].astype(str)
    s = df['Merge']
    s1 = '\n'.join(s)
    return s1

# %%
#Oct 18 edit: add a ";" to the end of each line. And this time I will use map instead of astype.

# %%
joinstr = ';' + ' '*10 + '\n'
joinstr
# Out:
# ';          \n'

# %%
#This is for counties
def TableOnline1(x):
    df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\CountyLevelData_All.xlsx', sheet_name = x)
    df['Merge'] = df['Counties'] + str(" "*5)+ df['Count'].map(str)
    s = df['Merge']
    s1 = ';   \n'.join(s)
    return s1

# %%
#Oct 19: do the same thing for the inflow data
#For Municipalities inflow:
def MuniIn(x):
    df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_In.xlsx', sheet_name = x)
    df['Merge'] = df['Municipalities'] + str("    ")+ df['Count'].astype(str)
    s = df['Merge']
    s1 = ';    \n'.join(s)
    return s1
#For Municipalities outflow:
def MuniOut(x):
    df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_In.xlsx', sheet_name = x)
    df['Merge'] = df['Municipalities'] + str("    ")+ df['Count'].astype(str)
    s = df['Merge']
    s1 = ';    \n'.join(s)
    return s1

# %%
#For Counties
def TableOnline1(x):
    df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\CountyLevelData_All_Inflow.xlsx', sheet_name = x)
    df['Merge'] = df['Counties'] + str("    ")+ df['Count'].map(str)
    s = df['Merge']
    s1 = ';   \n'.join(s)
    return s1

# %%
TableOnline('Allen')

# %%
pd.__version__

# %%
#Nov 1 change the function: get the destination and number columns separately.
def MuniInMunis(x):
    df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_Inflow.xlsx', sheet_name = x)
    s = df['Municipalities']
    s1 = '<br>    \n'.join(s)
    return s1
def MuniInCount(x):
    df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_Inflow.xlsx', sheet_name = x)
    s = df['Count'].map(str)
    s1 = '<br>    \n'.join(s)
    return s1
def MuniInShare(x):
    df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_Inflow.xlsx', sheet_name = x)
    s = df['Share'].map(str)
    s1 = '<br>    \n'.join(s)
    return s1

# %%
df.columns
# Out:
# Index(['Municipalities', 'Count', 'Share'], dtype='object')

# %%
#Nov 5 for Municipalities with HTML breake
def MuniIn(x):
    df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_In.xlsx', sheet_name = x)
    df['Merge'] = df['Municipalities'].str.title() + str("    ")+ df['Count'].astype(str)
    s = df['Merge']
    s1 = '<br>    \n'.join(s)
    return s1
def MuniOut(x):
    df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_Outflow.xlsx', sheet_name = x)
    df['Merge'] = df['Municipalities'] + str("    ")+ df['Count'].astype(str)
    s = df['Merge']
    s1 = '<br>    \n'.join(s)
    return s1

# %%
df.dtypes
# Out:
# Municipalities     object
# Count              object
# Share             float64
# dtype: object

# %%
df = pd.read_excel('file:///H:\lvpcprojects\FutureLV\ScenarioPlanning\
/LV_LivingWorkingFlow\LV_Worker_FlowII\MuniLevelData_All_Inflow.xlsx')
df['Municipalities'].str.title()
# Out:
# 0            Lower Macungie Township (Lehigh, Pa)
# 1                     Allentown City (Lehigh, Pa)
# 2                     Emmaus Borough (Lehigh, Pa)
# 3            Upper Macungie Township (Lehigh, Pa)
# 4             Upper Milford Township (Lehigh, Pa)
# 5                   Alburtis Borough (Lehigh, Pa)
# 6                  Longswamp Township (Berks, Pa)
# 7           South Whitehall Township (Lehigh, Pa)
# 8                      Lynn Township (Lehigh, Pa)
# 9                   Macungie Borough (Lehigh, Pa)
# 10          North Whitehall Township (Lehigh, Pa)
# 11                Salisbury Township (Lehigh, Pa)
# 12                Whitehall Township (Lehigh, Pa)
# 13               Bethlehem City (Northampton, Pa)
# 14                     Topton Borough (Berks, Pa)
# 15                 Maxatawny Township (Berks, Pa)
# 16               Weisenberg Township (Lehigh, Pa)
# 17          Northampton Borough (Northampton, Pa)
# 18                 Greenwich Township (Berks, Pa)
# ...

# %%
#Small Function to edit Truck Percentage:
def TruckText(x):
    if not x:
        Put = 'NA'
    else:
        Put = x + '%'
    return Put
str(round(15.233, 1))
# Out:
# '15.2'
