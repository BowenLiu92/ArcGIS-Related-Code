# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd

# %%
c1 = pd.read_csv(r"\\Fileserver01\d_drive\lvpcprojects\
/SlateBelt\Slate Belt Comprehensive Plan\research\Data\Census Data\ACS_17_5YR_DP03_with_ann.csv")
c1 = c1.set_index('GEO.display-label')
c1.T
c2 = c1.T
# Out:
# GEO.display-label                                          Geography  \
# GEO.id                                                            Id
# GEO.id2                                                          Id2
# HC01_VC03          Estimate; EMPLOYMENT STATUS - Population 16 ye...
# HC02_VC03          Margin of Error; EMPLOYMENT STATUS - Populatio...
# HC03_VC03          Percent; EMPLOYMENT STATUS - Population 16 yea...
# HC04_VC03          Percent Margin of Error; EMPLOYMENT STATUS - P...
# HC01_VC04          Estimate; EMPLOYMENT STATUS - Population 16 ye...
# HC02_VC04          Margin of Error; EMPLOYMENT STATUS - Populatio...
# HC03_VC04          Percent; EMPLOYMENT STATUS - Population 16 yea...
# HC04_VC04          Percent Margin of Error; EMPLOYMENT STATUS - P...
# HC01_VC05          Estimate; EMPLOYMENT STATUS - Population 16 ye...
# HC02_VC05          Margin of Error; EMPLOYMENT STATUS - Populatio...
# HC03_VC05          Percent; EMPLOYMENT STATUS - Population 16 yea...
# ...

# %%
r1 = pd.read_csv(r"\\Fileserver01\d_drive\lvpcprojects\
/SlateBelt\Slate Belt Comprehensive Plan\research\Data\Census Data\ACS_17_5YR_DP03_metadata.csv")
r1.head()
c2.head()
# Out:
#               GEO.id                                                 Id
# 0            GEO.id2                                                Id2
# 1  GEO.display-label                                          Geography
# 2          HC01_VC03  Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 3          HC02_VC03  Margin of Error; EMPLOYMENT STATUS - Populatio...
# 4          HC03_VC03  Percent; EMPLOYMENT STATUS - Population 16 yea...
# GEO.display-label                                          Geography  \
# GEO.id                                                            Id
# GEO.id2                                                          Id2
# HC01_VC03          Estimate; EMPLOYMENT STATUS - Population 16 ye...
# HC02_VC03          Margin of Error; EMPLOYMENT STATUS - Populatio...
# HC03_VC03          Percent; EMPLOYMENT STATUS - Population 16 yea...
#
# GEO.display-label Bangor borough, Northampton County, Pennsylvania  \
# ...

# %%
#Join the data and the metadata
df = pd.merge(c2, r1, left_index= True, right_on = 'GEO.id')
df.head()
# Out:
#                                            Geography  \
# 0                                                Id2
# 2  Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 3  Margin of Error; EMPLOYMENT STATUS - Populatio...
# 4  Percent; EMPLOYMENT STATUS - Population 16 yea...
# 5  Percent Margin of Error; EMPLOYMENT STATUS - P...
#
#   Bangor borough, Northampton County, Pennsylvania  \
# 0                                       4209504032
# 2                                             4196
# 3                                              189
# 4                                             4196
# 5                                              (X)
#
#   East Bangor borough, Northampton County, Pennsylvania  \
# 0                                         4209520776
# 2                                                772
# 3                                                117
# 4                                                772
# 5                                                (X)
#
# ...

# %%
#Now we need to filter df, first we just need the estimate
df = df[df.Geography.str.contains('Estimate')]
df
df= df.reset_index()
# Out:
#                                              Geography  \
# 2    Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 6    Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 10   Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 14   Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 18   Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 22   Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 26   Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 30   Estimate; EMPLOYMENT STATUS - Civilian labor f...
# 34   Estimate; EMPLOYMENT STATUS - Civilian labor f...
# 38   Estimate; EMPLOYMENT STATUS - Females 16 years...
# 42   Estimate; EMPLOYMENT STATUS - Females 16 years...
# 46   Estimate; EMPLOYMENT STATUS - Females 16 years...
# 50   Estimate; EMPLOYMENT STATUS - Females 16 years...
# 54   Estimate; EMPLOYMENT STATUS - Own children of ...
# 58   Estimate; EMPLOYMENT STATUS - Own children of ...
# 62   Estimate; EMPLOYMENT STATUS - Own children of ...
# ...

# %%
df
# Out:
#      index                                          Geography  \
# 0        2  Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 1        6  Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 2       10  Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 3       14  Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 4       18  Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 5       22  Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 6       26  Estimate; EMPLOYMENT STATUS - Population 16 ye...
# 7       30  Estimate; EMPLOYMENT STATUS - Civilian labor f...
# 8       34  Estimate; EMPLOYMENT STATUS - Civilian labor f...
# 9       38  Estimate; EMPLOYMENT STATUS - Females 16 years...
# 10      42  Estimate; EMPLOYMENT STATUS - Females 16 years...
# 11      46  Estimate; EMPLOYMENT STATUS - Females 16 years...
# 12      50  Estimate; EMPLOYMENT STATUS - Females 16 years...
# 13      54  Estimate; EMPLOYMENT STATUS - Own children of ...
# ...

# %%
df.loc[31:44].Geography = df.loc[31:44].Geography.str.replace('Estimate; INDUSTRY - Civilian employed population 16 years and over - ', '')
# Out:
# C:\Users\bliu\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df.loc[31:44]
# Out:
#     index                                          Geography  \
# 31    126  Estimate; INDUSTRY - Civilian employed populat...
# 32    130  Agriculture, forestry, fishing and hunting, an...
# 33    134                                       Construction
# 34    138                                      Manufacturing
# 35    142                                    Wholesale trade
# 36    146                                       Retail trade
# 37    150      Transportation and warehousing, and utilities
# 38    154                                        Information
# 39    158  Finance and insurance, and real estate and ren...
# 40    162  Professional, scientific, and management, and ...
# 41    166  Educational services, and health care and soci...
# 42    170  Arts, entertainment, and recreation, and accom...
# 43    174       Other services, except public administration
# 44    178                              Public administration
#
# ...

# %%
res = df.loc[31:44]
s = res.loc[32:44, 'Bangor borough, Northampton County, Pennsylvania'].astype(int).sum()
s
# Out:
# 2275

# %%
#Add a total sum row
colist = res.columns.tolist()
colist = [e for e in colist if e not in ('Geography', 'GEO.id', 'Id')]
colist

res.loc['Total Sum'] = res.loc[32:].sum(numeric_only = True)
# Out:
# ['Bangor borough, Northampton County, Pennsylvania',
#  'East Bangor borough, Northampton County, Pennsylvania',
#  'Lower Mount Bethel township, Northampton County, Pennsylvania',
#  'Pen Argyl borough, Northampton County, Pennsylvania',
#  'Plainfield township, Northampton County, Pennsylvania',
#  'Portland borough, Northampton County, Pennsylvania',
#  'Roseto borough, Northampton County, Pennsylvania',
#  'Upper Mount Bethel township, Northampton County, Pennsylvania',
#  'Washington township, Northampton County, Pennsylvania',
#  'Wind Gap borough, Northampton County, Pennsylvania']

# %%
res = res.drop(index = 'Total Sum')
res[colist] = res[colist].astype(int)

# %%
res1 = res.reset_index()

res1.loc['TotalSum'] = res1.loc[1:][colist].sum()
res1
# Out:
#           index                                          Geography  \
# 0          31.0  Estimate; INDUSTRY - Civilian employed populat...
# 1          32.0  Agriculture, forestry, fishing and hunting, an...
# 2          33.0                                       Construction
# 3          34.0                                      Manufacturing
# 4          35.0                                    Wholesale trade
# 5          36.0                                       Retail trade
# 6          37.0      Transportation and warehousing, and utilities
# 7          38.0                                        Information
# 8          39.0  Finance and insurance, and real estate and ren...
# 9          40.0  Professional, scientific, and management, and ...
# 10         41.0  Educational services, and health care and soci...
# 11         42.0  Arts, entertainment, and recreation, and accom...
# 12         43.0       Other services, except public administration
# ...

# %%
res1.to_csv('Census Employment Data.csv')

# %%
res.sum(numeric_only= True)
# Out:
# Bangor borough, Northampton County, Pennsylvania                 4550
# East Bangor borough, Northampton County, Pennsylvania             886
# Lower Mount Bethel township, Northampton County, Pennsylvania    3052
# Pen Argyl borough, Northampton County, Pennsylvania              3730
# Plainfield township, Northampton County, Pennsylvania            6762
# Portland borough, Northampton County, Pennsylvania                430
# Roseto borough, Northampton County, Pennsylvania                 1822
# Upper Mount Bethel township, Northampton County, Pennsylvania    7220
# Washington township, Northampton County, Pennsylvania            5362
# Wind Gap borough, Northampton County, Pennsylvania               2586
# dtype: int64

# %%
dfr = df[df.Geography.str.contains('Retail')]
dfr
# Out:
#     index     Geography Bangor borough, Northampton County, Pennsylvania  \
# 36    146  Retail trade                                              291
#
#    East Bangor borough, Northampton County, Pennsylvania  \
# 36                                                 39
#
#    Lower Mount Bethel township, Northampton County, Pennsylvania  \
# 36                                                125
#
#    Pen Argyl borough, Northampton County, Pennsylvania  \
# 36                                                169
#
#    Plainfield township, Northampton County, Pennsylvania  \
# 36                                                670
#
#    Portland borough, Northampton County, Pennsylvania  \
# 36                                                 11
#
#    Roseto borough, Northampton County, Pennsylvania  \
# 36                                              119
#
#    Upper Mount Bethel township, Northampton County, Pennsylvania  \
# 36                                                439
#
# ...
