# %%
import googlemaps

#My keyID  AIzaSyAgaUJgH1LLvEww8rQ7dOFg1W2IyDcKDHM

import pandas as pd

# %%
# Set Google Maps API key

my_google_maps_key = googlemaps.Client(key = 'AIzaSyAgaUJgH1LLvEww8rQ7dOFg1W2IyDcKDHM')

# %%
# The table of the shopping centers

df = pd.read_csv('file:///\\Fileserver01\d_drive\lvpcprojects\
/FutureLV\Shopping%20Centers\SWLehigh%20Southern%20Tier%20Shopping%20Centers.csv')[['LOCATION']]
df
# Out:
#                                             LOCATION
# 0                 Hamilton Blvd, Allentown, PA 18106
# 1          6900 Hamilton Blvd, Trexlertown, PA 18087
# 2          7150 Hamilton Blvd, Trexlertown, PA 18087
# 3           7150 Hamilton Blvd Trexlertown, PA 18087
# 4                 7001 PA-309, Coopersburg, PA 18036
# 5                   3691 PA-378, Bethlehem, PA 18015
# 6                                       Upper Saucon
# 7   2845 Center Valley Pkwy, Center Valley, PA 18034
# 8          216 E Fairmount St, Coopersburg, PA 18036
# 9          1880 Leithsville Rd, Hellertown, PA 18055
# 10           1091 Mill Creek Rd, Allentown, PA 18106
# 11                                Hamilton Boulevard
# 12                                Hamilton Boulevard

# %%
#Create Geocode result object and get Lon and Lat
df['LAT'] = None
df['LON'] = None

for i in range(len(df)):
    geocode_result = my_google_maps_key.geocode(df.iat[i, 0])
    try:
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lon = geocode_result[0]["geometry"]["location"]["lng"]
        df.iat[i, df.columns.get_loc("LAT")] = lat
        df.iat[i, df.columns.get_loc("LON")] = lon
    except:
        lat = None
        lon - None
# Out:
# ---------------------------------------------------------------------------
# _OverQueryLimit                           Traceback (most recent call last)
# C:\Users\bliu\AppData\Local\Continuum\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# C:\Users\bliu\AppData\Local\Continuum\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# ...

# %%
#Play around with get_loc

df1 = pd.DataFrame({"pear": [1,2,3], "apple": [2,3,4], "orange": [3,4,5]})
df1
