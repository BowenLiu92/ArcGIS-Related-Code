# %%
import numpy as np
import pandas as pd

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
df = pd.read_excel(r"L:\lvpcgis\LandUse\ExistingLandUse\2018LandUse\LC_ELU18_Edit.xlsx")
df.head()
df.columns
# Out:
#    OBJECTID  FID_TotalDifferentParcels2018  ParcelType  ELU18    ELU18Text  \
# 0         1                            287         1.0      1  Residential
# 1         2                             -1         0.0      0          NaN
# 2         3                             -1         0.0      0          NaN
# 3         4                             -1         0.0      0          NaN
# 4         5                             -1         0.0      0          NaN
#
#      GISAcres  FID_LC_ELU_2016Baseline  MUNICODE  LVPCGENC  SUM_19_Par  \
# 0    0.629596                       -1         0         1           0
# 1  796.741739                        1         0       990           0
# 2  185.098512                        2         1         1           0
# 3    6.097628                        3         1         2           0
# 4    7.969384                        4         1         3           0
#
#    SUM_Res_1_  SUM_RCOB_2  SUM_ManuIn  SUM_WareDi  SUM_TCU_6_  SUM_PubQua  \
# ...

# %%
sublist.index('SUM_TCU_6_')
# Out:
# 4

# %%
sublist = ['SUM_Res_1_', 'SUM_RCOB_2', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe']
#Use dictionary here is probably better
d = {}
for i in range(4):
    d['sub' + str(i)] = [v for e,v in enumerate(sublist) if e != i]
d['sub4'] = ['SUM_Res_1_', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe']
for i in range(4, 8):
    d['sub' + str(i+1)] = [v for e,v in enumerate(sublist) if e != i]

# %%
d
# Out:
# {'sub0': ['SUM_RCOB_2',
#   'SUM_ManuIn',
#   'SUM_WareDi',
#   'SUM_TCU_6_',
#   'SUM_PubQua',
#   'SUM_ParksR',
#   'SUM_AgUnDe'],
#  'sub1': ['SUM_Res_1_',
#   'SUM_ManuIn',
#   'SUM_WareDi',
#   'SUM_TCU_6_',
#   'SUM_PubQua',
#   'SUM_ParksR',
#   'SUM_AgUnDe'],
#  'sub2': ['SUM_Res_1_',
#   'SUM_RCOB_2',
#   'SUM_WareDi',
#   'SUM_TCU_6_',
#   'SUM_PubQua',
#   'SUM_ParksR',
#   'SUM_AgUnDe'],
#  'sub3': ['SUM_Res_1_',
#   'SUM_RCOB_2',
#   'SUM_ManuIn',
#   'SUM_TCU_6_',
#   'SUM_PubQua',
#   'SUM_ParksR',
#   'SUM_AgUnDe'],
#  'sub4': ['SUM_Res_1_',
#   'SUM_ManuIn',
#   'SUM_WareDi',
#   'SUM_TCU_6_',
#   'SUM_PubQua',
#   'SUM_ParksR',
#   'SUM_AgUnDe'],
#  'sub5': ['SUM_Res_1_',
#   'SUM_RCOB_2',
#   'SUM_ManuIn',
#   'SUM_WareDi',
#   'SUM_PubQua',
#   'SUM_ParksR',
#   'SUM_AgUnDe'],
#  'sub6': ['SUM_Res_1_',
#   'SUM_RCOB_2',
#   'SUM_ManuIn',
#   'SUM_WareDi',
#   'SUM_TCU_6_',
#   'SUM_ParksR',
#   'SUM_AgUnDe'],
#  'sub7': ['SUM_Res_1_',
#   'SUM_RCOB_2',
# ...

# %%
sublist = ['SUM_Res_1_', 'SUM_RCOB_2', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe']
#Use dictionary here is probably better
d = {}
d['sub1'] = ['SUM_RCOB_2', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe']
d['sub2'] = ['SUM_Res_1_', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe']
d['sub3'] = ['SUM_Res_1_', 'SUM_RCOB_2', 
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe']
d['sub4'] = ['SUM_Res_1_', 'SUM_RCOB_2', 'SUM_ManuIn',
       'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe']
#sub5 is also categorized as Retail&Commercial, so same as sub2
d['sub5'] = ['SUM_Res_1_', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe']
d['sub6'] = ['SUM_Res_1_', 'SUM_RCOB_2', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe']
d['sub7'] = ['SUM_Res_1_', 'SUM_RCOB_2', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_ParksR', 'SUM_AgUnDe']
d['sub8'] = ['SUM_Res_1_', 'SUM_RCOB_2', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_AgUnDe']
d['sub9'] = ['SUM_Res_1_', 'SUM_RCOB_2', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR']

#I have been so stupid, this cell stays to show how stupid I've been

# %%
collist = ['OBJECTID', 'FID_TotalDifferentParcels2018', 'ELU18',
       'GISAcres', 'FID_LC_ELU_2016Baseline', 'MUNICODE',
       'LVPCGENC', 'SUM_19_Par', 'SUM_Res_1_', 'SUM_RCOB_2', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe',
       ]
e = df[collist]
e.head(10)
# Out:
#    OBJECTID  FID_TotalDifferentParcels2018  ELU18    GISAcres  \
# 0         1                            287      1    0.629596
# 1         2                             -1      0  796.741739
# 2         3                             -1      0  185.098512
# 3         4                             -1      0    6.097628
# 4         5                             -1      0    7.969384
# 5         6                             -1      0    1.288890
# 6         7                             -1      0    5.260547
# 7         8                             -1      0   11.884449
# 8         9                             -1      0   65.537753
# 9        10                             -1      0  107.417767
#
#    FID_LC_ELU_2016Baseline  MUNICODE  LVPCGENC  SUM_19_Par  SUM_Res_1_  \
# 0                       -1         0         1           0    0.629596
# 1                        1         0       990           0    0.000000
# ...

# %%
df.head()
e = df[collist]
# Out:
#    OBJECTID  FID_TotalDifferentParcels2018  ParcelType  ELU18    ELU18Text  \
# 0         1                            287         1.0      1  Residential
# 1         2                             -1         0.0      0          NaN
# 2         3                             -1         0.0      0          NaN
# 3         4                             -1         0.0      0          NaN
# 4         5                             -1         0.0      0          NaN
#
#      GISAcres  FID_LC_ELU_2016Baseline  MUNICODE  LVPCGENC  SUM_19_Par  \
# 0    0.629596                       -1         0         1           0
# 1  796.741739                        1         0       990           0
# 2  185.098512                        2         1         1           0
# 3    6.097628                        3         1         2           0
# 4    7.969384                        4         1         3           0
#
#    SUM_Res_1_  SUM_RCOB_2  SUM_ManuIn  SUM_WareDi  SUM_TCU_6_  SUM_PubQua  \
# ...

# %%
#With the created dictionary, let's see if we can clean the df in a loop

e.loc[e.LVPCGENC == 1, d['sub0']] = 0

#The cleanup seems to have worked. Ignore the warning since we are obviously doing this on a copy
for i in range(9):
    df.loc[df.LVPCGENC == i+1, d['sub' + str(i)]] = 0
# Out:
# C:\Users\bliu\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
#Clean the Ag Column for GENC 19.
df.loc[df.LVPCGENC == 19, 'SUM_AgUnDe'] = df.GISAcres - df.SUM_Res_1_

# %%
df[(df.FID_TotalDifferentParcels2018 != -1) & (df.LVPCGENC == 19)][['GISAcres', 'LVPCGENC', 'SUM_19_Par', 'SUM_Res_1_', 'SUM_AgUnDe']]
# Out:
#        GISAcres  LVPCGENC  SUM_19_Par  SUM_Res_1_  SUM_AgUnDe
# 347   16.793455        19           1    5.000000   11.793455
# 508   20.312829        19           1    5.000000   15.312829
# 550   29.965609        19           1    5.000000   24.965609
# 565    0.424695        19           1    0.424695    0.000000
# 566    0.354306        19           1    0.354306    0.000000
# 567   11.211260        19           1    5.000000    6.211260
# 568    0.001564        19           1    0.001564    0.000000
# 595    0.886155        19           1    0.886155    0.000000
# 596   49.640911        19           1    5.000000   44.640911
# 670   10.796432        19           1    5.000000    5.796432
# 691   13.672993        19           1    5.000000    8.672993
# 735   34.877120        19           1    5.000000   29.877120
# 750    0.181285        19           1    0.181285    0.000000
# 751   11.158410        19           1    5.000000    6.158410
# ...

# %%
#Clean other columns for GENCCODE 
list19 = ['SUM_RCOB_2', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR']
df.loc[df.LVPCGENC == 19, list19] = 0

# %%
df.tail(10)
# Out:
#       OBJECTID  FID_TotalDifferentParcels2018  ParcelType  ELU18  \
# 2120      2121                            616         1.0      1
# 2121      2122                            616         1.0      1
# 2122      2123                            657         1.0     19
# 2123      2124                            657         1.0     19
# 2124      2125                            731         1.0      4
# 2125      2126                            731         1.0      4
# 2126      2127                            731         1.0      4
# 2127      2128                            731         1.0      4
# 2128      2129                            736         1.0      1
# 2129      2130                            736         1.0      1
#
#                        ELU18Text  GISAcres  FID_LC_ELU_2016Baseline  MUNICODE  \
# 2120                 Residential  0.001227                      219        53
# 2121                 Residential  0.001227                      221        53
# ...

# %%
df.to_clipboard()

# %%
g = df.groupby(['MUNICODE', 'LVPCGENC'])['SUM_19_Par', 'SUM_Res_1_', 'SUM_RCOB_2', 'SUM_ManuIn',
       'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe'].sum()
g.head(15)
# Out:
#                    SUM_19_Par   SUM_Res_1_  SUM_RCOB_2  SUM_ManuIn  \
# MUNICODE LVPCGENC
# 0        1                  0     0.629596    0.000000    0.000000
#          990                0     0.000000    0.000000    0.000000
# 1        1                  0   185.919967    0.000000    0.000000
#          2                  0     0.000000    6.097628    0.000000
#          3                  0     0.000000    0.000000    7.969384
#          5                  0     0.000000    1.288890    0.000000
#          6                  0     0.000000    0.000000    0.000000
#          7                  0     0.000000    0.000000    0.000000
#          8                  0     0.000000    0.000000    0.000000
#          9                  0     0.000000    0.000000    0.000000
#          19                 1     5.000000    0.000000    0.000000
#          990                0     0.000000    0.000000    0.000000
# 3        1                  0  3641.333328    0.000000    0.000000
# ...

# %%
g.to_clipboard()

# %%
df.columns
# Out:
# Index(['OBJECTID', 'FID_TotalDifferentParcels2018', 'ParcelType', 'ELU18',
#        'ELU18Text', 'GISAcres', 'FID_LC_ELU_2016Baseline', 'MUNICODE',
#        'LVPCGENC', 'SUM_19_Par', 'SUM_Res_1_', 'SUM_RCOB_2', 'SUM_ManuIn',
#        'SUM_WareDi', 'SUM_TCU_6_', 'SUM_PubQua', 'SUM_ParksR', 'SUM_AgUnDe',
#        'Shape_Length', 'Shape_Area'],
#       dtype='object')

# %%
import rasterio
rasterio.open(r"L:\lvpcgis\BowenLiuTemporary\ExtendLinesToLayer\Test\47002600PAS_dem.tif")
# Out:
# <open DatasetReader name='L:\lvpcgis\BowenLiuTemporary\ExtendLinesToLayer\Test\47002600PAS_dem.tif' mode='r'>

# %%
with rasterio.open(r"L:\lvpcgis\BowenLiuTemporary\ExtendLinesToLayer\Test\47002600PAS_dem.tif") as src:
    profile = src
# Out:
# array([[[ 375.36999512,  375.32000732,  375.26998901, ...,  226.72999573,
#           226.72999573,  226.72999573],
#         [ 375.30999756,  375.3500061 ,  375.29998779, ...,  226.72999573,
#           226.72999573,  226.72999573],
#         [ 375.26000977,  375.32000732,  375.32998657, ...,  226.72999573,
#           226.72999573,  226.72999573],
#         ...,
#         [ 368.3999939 ,  368.41000366,  368.42999268, ...,  691.46002197,
#           691.97998047,  692.59997559],
#         [ 368.41000366,  368.42999268,  368.45001221, ...,  691.76000977,
#           692.2800293 ,  692.79998779],
#         [ 368.42999268,  368.45001221,  368.45999146, ...,  692.05999756,
#           692.78997803,  693.60998535]]], dtype=float32)
